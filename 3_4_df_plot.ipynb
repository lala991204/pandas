# %% [markdown]
# <a href="https://colab.research.google.com/github/lala991204/pandas/blob/master/3_4_df_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/pandas/남북한발전전력량.xlsx', engine ='openpyxl')     # 데이터프레임 변환

df_ns = df.iloc[[0, 5], 3:]                 # 남한, 북한 발전량 합계 데이터만 추출
df_ns.index = ['South', 'North']            # 행 인덱스 변경
df_ns.columns = df_ns.columns.map(int)      # 열 이름의 자료형을 정수형으로 변경
print(df_ns.head())
print('\n')

# 선 그래프 그리기
df_ns.plot()
# Out:
#        1991  1992  1993  1994  1995  1996  ...  2011  2012  2013  2014  2015  2016
# South  1186  1310  1444  1650  1847  2055  ...  4969  5096  5171  5220  5281  5404
# North   263   247   221   231   230   213  ...   211   215   221   216   190   239
#
# [2 rows x 26 columns]
